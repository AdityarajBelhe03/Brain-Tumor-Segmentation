# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
from model import build_unet
from metrics import dice_loss, dice_coef, iou
from tensorflow.keras.applications import VGG16, ResNet50, MobileNet
from tensorflow.keras.layers import Concatenate, Conv2D, UpSampling2D,Input
from tensorflow.keras.models import Model
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

# %%
H = 128
W = 128

# %%
def create_dir(path):
    """ Create a directory. """
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

# %%
def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.jpg")))
    y = sorted(glob(os.path.join(path, "mask", "*.jpg")))
    return x, y

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x/255.0
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = x/255.0
    x = x > 0.5
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

# %%
def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
  """ Seeding """
np.random.seed(42)
tf.random.set_seed(42)

# %%
""" Directory for storing files """
create_dir("files")

# %%
    """ Hyperparameters """
    batch_size = 8
    lr = 1e-3
    num_epochs = 15
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "data.csv")

# %%
    """ Dataset """
    dataset_path = os.path.join("new_data")
    train_path = os.path.join(dataset_path, "train")
    valid_path = os.path.join(dataset_path, "valid")
    
    train_x, train_y = load_data(train_path)
    train_x, train_y = shuffling(train_x, train_y)
    valid_x, valid_y = load_data(valid_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
# Out:
# Train: 2344 - 2344
# Valid: 260 - 260

# %%
    """ Model """
    model = build_unet((H, W, 3))
    metrics = ['accuracy',dice_coef, iou, Recall(), Precision()]
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=metrics)
    model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_50 (Conv2D)             (None, 128, 128, 32  896         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 32  128        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 32  9248        ['activation_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 32  128        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_49[0][0]']
#  )
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_51[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_51[0][0]']
#  )
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_11[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_53[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_53[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_55[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 8, 8, 256)   0           ['activation_55[0][0]']
#  )
#
#  conv2d_58 (Conv2D)             (None, 8, 8, 512)    1180160     ['max_pooling2d_13[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#  activation_56 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_57[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 4, 4, 512)   0           ['activation_57[0][0]']
#  )
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 1024)   4719616     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 4, 4, 1024)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 4, 4, 1024)   9438208     ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 4, 4, 1024)   0           ['batch_normalization_59[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 4, 4, 1024)   9438208     ['activation_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 4, 4, 1024)   0           ['batch_normalization_60[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 4, 4, 1024)   9438208     ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 4, 4, 1024)  4096        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 4, 4, 1024)   0           ['batch_normalization_61[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 8, 8, 512)   2097664     ['activation_61[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 8, 8, 1024)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'activation_57[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 8, 8, 512)    4719104     ['concatenate_10[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 8, 8, 512)    2359808     ['activation_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_63[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 16, 16, 256)  524544     ['activation_63[0][0]']
#  nspose)
#
#  concatenate_11 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_transpose_11[0][0]',
#                                                                   'activation_55[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_11[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 32, 32, 128)  131200     ['activation_65[0][0]']
#  nspose)
#  concatenate_12 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'activation_53[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_12[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 32, 32, 128)  512        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 128)  512        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_67[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 64, 64, 64)  32832       ['activation_67[0][0]']
#  nspose)
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_13[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 64, 64, 64)  256         ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_68[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_68[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 64, 64, 64)  256         ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_69[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 128, 128, 32  8224       ['activation_69[0][0]']
#  nspose)                        )
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_14[0][0]',
#                                 )                                 'activation_49[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_14[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 128, 128, 32  128        ['conv2d_72[0][0]']
#  ormalization)                  )
#
#  activation_70 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_70[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 128, 128, 32  9248        ['activation_70[0][0]']
#                                 )
#
#  batch_normalization_71 (BatchN  (None, 128, 128, 32  128        ['conv2d_73[0][0]']
#  ormalization)                  )
#
#  activation_71 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_71[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 128, 128, 1)  33          ['activation_71[0][0]']
#
# ==================================================================================================
# Total params: 50,003,169
# Trainable params: 49,987,041
# Non-trainable params: 16,128
# __________________________________________________________________________________________________

# %%
    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False),
    ]

# %%
history=model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks,
        shuffle=False
    )
# Out:
# Epoch 1/15
# 222/293 [=====================>........] - ETA: 10s - loss: 0.7847 - accuracy: 0.9110 - dice_coef: 0.2153 - iou: 0.1261 - recall_2: 0.6262 - precision_2: 0.1168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 history=model.fit(
#       2         train_dataset,
#       3         epochs=num_epochs,
#       4         validation_data=valid_dataset,
#       5         callbacks=callbacks,
#       6         shuffle=False
#       7     )
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib

# %%
# Plot the training and validation loss vs. epochs
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation accuracy vs. epochs
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
